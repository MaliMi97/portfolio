# %%
import numpy as np
import matplotlib.pyplot as plt
from TASEP import *
from DataProcessing import *
from Results import *

# %%
# sets parameters for the computation
parametres = np.arange(0.05,1.05,0.05)
length = 10
number_of_particles = 0
time = 1_000

# %%
# we will use the Parallel algorithm first
tasep = TASEP_Parallel(length, number_of_particles, time)

# %%
# processes the data
d = DataProcessing(tasep.execute(0.5, 0.5, 0.5))

# %%
# plots the particle density over time and the 100th moving average of particle flow
d.plot_decide_start(200)

# %%
# from the results above, we decide that we will start measuting from time 200 s
result_parallel = get_result(tasep, 0.5, parametres, 200)
# Out:
# 0.05
# 0.1
# 0.15000000000000002
# 0.2
# 0.25
# 0.3
# 0.35000000000000003
# 0.4
# 0.45
# 0.5
# 0.55
# 0.6000000000000001
# 0.6500000000000001
# 0.7000000000000001
# 0.7500000000000001
# 0.8
# 0.8500000000000001
# 0.9000000000000001
# 0.9500000000000001
# 1.0

# %%
plot_result(result_parallel, parametres)

# %%
# now we repeat the process for random algorithm
tasep = TASEP_Random(length, number_of_particles, time)

# %%
d = DataProcessing(tasep.execute(0.5, 0.5, 0.5))

# %%
d.plot_decide_start(100)

# %%
result_random = get_result(tasep, 0.5, parametres, 200)
# Out:
# 0.05
# 0.1
# 0.15000000000000002
# 0.2
# 0.25
# 0.3
# 0.35000000000000003
# 0.4
# 0.45
# 0.5
# 0.55
# 0.6000000000000001
# 0.6500000000000001
# 0.7000000000000001
# 0.7500000000000001
# 0.8
# 0.8500000000000001
# 0.9000000000000001
# 0.9500000000000001
# 1.0

# %%
plot_result(result_random, parametres)

# %%
plot_compare(result_parallel, result_random)
