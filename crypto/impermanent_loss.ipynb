# %% [markdown]
# In this jupiter-notebook the impermanent losses of some LP pairs are graphed. The statistical variables such as mean and standard deviation are also displayed. For now, we do not count with rehypothecation.

# %%
from functions.impermanent_loss import *
from api.CoinGeckoAPI import CoinGeckoAPI
from visualization.line_graph import *
import numpy as np
import pandas as pd
import datetime

# %%
c = CoinGeckoAPI()

# %%
df = c.get_price_cap_volume(datetime.datetime(2021, 11, 1), datetime.datetime.today(), 'week', 'defi-kingdoms')\
    .merge(c.get_price_cap_volume(datetime.datetime(2021, 11, 1), datetime.datetime.today(), 'week', 'harmony'), on='time')
df['price_reward'] = df['price_x']
df = impermanent_loss(df, 200, 2.80/365*7, 0)
impermanent_loss_vis(df, 'Jewel', "One")
print(df[['% to x', '% to y', '% to 50/50']].describe())
# Out:
#            % to x       % to y  % to 50/50
# count   14.000000    14.000000   14.000000
# mean   188.642920   629.748432  309.292426
# std    149.456635   419.125530  219.538218
# min     -0.881986     0.000000    0.000000
# 25%     71.186234   258.155865  131.648228
# 50%    153.587056   717.035421  287.045039
# 75%    322.487202  1000.634502  513.506046
# max    424.569696  1131.168581  635.683372

# %%
df = c.get_price_cap_volume(datetime.datetime(2021, 9, 1), datetime.datetime.today(), 'week', 'defi-kingdoms')\
    .merge(c.get_price_cap_volume(datetime.datetime(2021, 9, 1), datetime.datetime.today(), 'week', 'harmony'), on='time')
df['price_reward'] = df['price_x']
df = impermanent_loss(df, 200, 2.80/365*7, 0.5)
impermanent_loss_vis(df, 'Jewel', "One")
print(df[['% to x', '% to y', '% to 50/50']].describe())
# Out:
#            % to x       % to y  % to 50/50
# count   19.000000    19.000000   19.000000
# mean    40.393181   845.477444  134.473746
# std     60.632925   689.417465  120.769662
# min    -30.920893     0.000000    0.000000
# 25%     -3.677176   154.702942   35.309259
# 50%     18.121412   680.988517  105.206201
# 75%     75.254408  1590.423106  219.555802
# max    160.635005  1809.752666  358.672340

# %%
df = c.get_price_cap_volume(datetime.datetime(2021, 9, 1), datetime.datetime.today(), 'week', 'spookyswap')\
    .merge(c.get_price_cap_volume(datetime.datetime(2021, 9, 1), datetime.datetime.today(), 'week', 'fantom'), on='time')
df['price_reward'] = df['price_x']
df = impermanent_loss(df, 200, 0.6/365*7, 1)
impermanent_loss_vis(df, 'BOO', "Fantom")
print(df[['% to x', '% to y', '% to 50/50']].describe())
# Out:
#           % to x     % to y    % to 50/50
# count  23.000000  23.000000  2.300000e+01
# mean   29.517706   0.584250  1.251025e+01
# std    16.929011   8.947247  8.654106e+00
# min    -2.611422 -12.571152  1.421085e-14
# 25%    22.049452  -5.294229  4.631554e+00
# 50%    31.864750  -1.859985  1.155010e+01
# 75%    41.687454   5.878149  1.797190e+01
# max    56.942317  20.336949  2.763993e+01

# %%
df = c.get_price_cap_volume(datetime.datetime(2021, 9, 1), datetime.datetime.today(), 'week', 'spookyswap')\
    .merge(c.get_price_cap_volume(datetime.datetime(2021, 9, 1), datetime.datetime.today(), 'week', 'fantom'), on='time')
df['price_reward'] = df['price_x']
df = impermanent_loss(df, 200, 0.6/365*7,0)
impermanent_loss_vis(df, 'BOO', "Fantom")
print(df[['% to x', '% to y', '% to 50/50']].describe())
# Out:
#              % to x        % to y    % to 50/50
# count  2.300000e+01  2.300000e+01  2.300000e+01
# mean   3.155252e+02  2.159993e+02  2.572458e+02
# std    1.981282e+02  1.528559e+02  1.704582e+02
# min    1.421085e-14  1.421085e-14  1.421085e-14
# 25%    1.521922e+02  7.724830e+01  1.080545e+02
# 50%    3.389160e+02  2.007543e+02  2.598949e+02
# 75%    4.732430e+02  2.767958e+02  3.486096e+02
# max    6.389221e+02  5.081505e+02  5.496876e+02
