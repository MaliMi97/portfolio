# %% [markdown]
# In this jupiter-notebook the impermanent losses of some LP pairs are graphed. The statistical variables such as mean and standard deviation are also displayed. For now, we do not count with rehypothecation.

# %%
from functions.impermanent_loss import *
from api.CoinGeckoAPI import CoinGeckoAPI
from visualization.line_graph import *
import numpy as np
import pandas as pd
import datetime

# %%
c = CoinGeckoAPI()

# %%
df = c.get_closing_price(datetime.datetime(2021, 11, 1), datetime.datetime.today(), 'week', 'defi-kingdoms')\
    .merge(c.get_closing_price(datetime.datetime(2021, 11, 1), datetime.datetime.today(), 'week', 'harmony'), on='time')
df['price_reward'] = df['price_x']
df = impermanent_loss(df, 2002.80/365*7, 0)
impermanent_loss_vis(df, 'Jewel', "One")
print(df[['% to x', '% to y', '% to 50/50']].describe())
# Out:
#           % to x      % to y  % to 50/50
# count  14.000000   14.000000   14.000000
# mean  -38.485794   69.981630  -13.058728
# std    15.163482   33.323963    7.231418
# min   -52.783441    0.000000  -22.781910
# 25%   -49.693869   59.480366  -19.811614
# 50%   -41.917447   72.170572  -13.138846
# 75%   -37.269802   99.337752   -9.987734
# max     0.000000  111.790106    0.000000

# %%
df = c.get_closing_price(datetime.datetime(2021, 9, 1), datetime.datetime.today(), 'week', 'defi-kingdoms')\
    .merge(c.get_closing_price(datetime.datetime(2021, 9, 1), datetime.datetime.today(), 'week', 'harmony'), on='time')
df['price_reward'] = df['price_x']
df = impermanent_loss(df, 200, 2.80/365*7, 0.5)
impermanent_loss_vis(df, 'Jewel', "One")
print(df[['% to x', '% to y', '% to 50/50']].describe())
# Out:
#            % to x       % to y  % to 50/50
# count   18.000000    18.000000   18.000000
# mean    33.713079   791.906598  122.018269
# std     54.725521   667.473384  111.005588
# min    -30.920893     0.000000    0.000000
# 25%     -5.515765   137.652532   32.899552
# 50%     12.925218   640.659782   95.969897
# 75%     59.425167  1519.360995  191.205932
# max    147.979125  1774.050203  334.059131

# %%
df = c.get_closing_price(datetime.datetime(2021, 9, 1), datetime.datetime.today(), 'week', 'spookyswap')\
    .merge(c.get_closing_price(datetime.datetime(2021, 9, 1), datetime.datetime.today(), 'week', 'fantom'), on='time')
df['price_reward'] = df['price_x']
df = impermanent_loss(df, 200, 0.6/365*7, 1)
impermanent_loss_vis(df, 'BOO', "Fantom")
print(df[['% to x', '% to y', '% to 50/50']].describe())
# Out:
#           % to x     % to y  % to 50/50
# count  23.000000  23.000000   23.000000
# mean   48.847842 -12.632110    9.135228
# std    21.930288   7.993806    7.845139
# min     0.000000 -24.202312   -0.228054
# 25%    38.774112 -17.893481    2.531619
# 50%    54.785262 -14.916114    7.659115
# 75%    63.754274  -8.207428   12.621362
# max    84.394743   4.327835   25.430047

# %%
df = c.get_closing_price(datetime.datetime(2021, 9, 1), datetime.datetime.today(), 'week', 'spookyswap')\
    .merge(c.get_closing_price(datetime.datetime(2021, 9, 1), datetime.datetime.today(), 'week', 'fantom'), on='time')
df['price_reward'] = df['price_x']
df = impermanent_loss(df, 200, 0.6/365*7,0)
impermanent_loss_vis(df, 'BOO', "Fantom")
print(df[['% to x', '% to y', '% to 50/50']].describe())
# Out:
#            % to x      % to y  % to 50/50
# count   23.000000   23.000000   23.000000
# mean   372.122221  167.967043  239.849956
# std    230.312026  128.863691  163.416389
# min      0.000000    0.000000    0.000000
# 25%    174.396961   58.381000  100.260225
# 50%    397.173140  164.711525  245.478695
# 75%    554.778490  211.695931  318.055407
# max    736.959643  437.517794  552.897906
