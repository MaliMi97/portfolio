# %% [markdown]
# In this jupiter-notebook the impermanent losses of some LP pairs are graphed. The statistical variables such as mean and standard deviation are also displayed. For now, we do not count with rehypothecation.

# %%
from functions.impermanent_loss import *
from api.CoinGeckoAPI import CoinGeckoAPI
from visualization.line_graph import *
import numpy as np
import pandas as pd
import datetime

# %%
c = CoinGeckoAPI()

# %%
df = c.get_closing_price(datetime.datetime(2021, 11, 1), datetime.datetime.today(), 'week', 'defi-kingdoms')\
    .merge(c.get_closing_price(datetime.datetime(2021, 11, 1), datetime.datetime.today(), 'week', 'harmony'), on='time')
df = impermanent_loss(df, 200)
impermanent_loss_vis(df, 'Jewel', "One")
print(df[['% to x', '% to y', '% to 50/50']].describe())
# Out:
#           % to x      % to y  % to 50/50
# count  14.000000   14.000000   14.000000
# mean  -38.485794   69.981630  -13.058728
# std    15.163482   33.323963    7.231418
# min   -52.783441    0.000000  -22.781910
# 25%   -49.693869   59.480366  -19.811614
# 50%   -41.917447   72.170572  -13.138846
# 75%   -37.269802   99.337752   -9.987734
# max     0.000000  111.790106    0.000000

# %%
df = c.get_closing_price(datetime.datetime(2021, 9, 1), datetime.datetime.today(), 'week', 'spookyswap')\
    .merge(c.get_closing_price(datetime.datetime(2021, 9, 1), datetime.datetime.today(), 'week', 'fantom'), on='time')
df = impermanent_loss(df, 200)
impermanent_loss_vis(df, 'BOO', "Fantom")
print(df[['% to x', '% to y', '% to 50/50']].describe())
# Out:
#           % to x     % to y  % to 50/50
# count  23.000000  23.000000   23.000000
# mean   30.661118 -22.709988   -3.775704
# std    12.743530   8.166672    2.193292
# min     0.000000 -34.291367   -8.212940
# 25%    23.429038 -28.656796   -5.442330
# 50%    33.012388 -24.819033   -3.935455
# 75%    40.168009 -18.967757   -2.181240
# max    52.187004   0.000000    0.000000
